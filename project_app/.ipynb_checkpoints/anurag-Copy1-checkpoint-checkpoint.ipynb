# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("data (1).csv")
df
# Out:
#      nsites formula_pretty      volume   density symmetry__crystal_system  \
# 0        44        Ti19N25  487.283476  4.292537                 Trigonal
# 1         6           Ti2N   75.787718  4.808925               Tetragonal
# 2         6           Ti2N   74.005460  4.924737               Tetragonal
# 3         4           Ti3N   52.721158  4.964112               Tetragonal
# 4         4           Ti3N   50.526036  5.179780                    Cubic
# ..      ...            ...         ...       ...                      ...
# 207      16        Ti3N2O3  183.048704  3.984462               Monoclinic
# 208      16        Ti3N2O3  188.522001  3.868782             Orthorhombic
# 209      16        Ti3N2O3  183.615175  3.972170             Orthorhombic
# 210      16        Ti3N2O3  187.974167  3.880058               Monoclinic
# 211      16         Ti3NO4  185.907408  3.958791             Orthorhombic
#
#     symmetry__symbol  symmetry__number symmetry__point_group  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212 entries, 0 to 211
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   nsites                     212 non-null    int64
#  1   formula_pretty             212 non-null    object
#  2   volume                     212 non-null    float64
#  3   density                    212 non-null    float64
#  4   symmetry__crystal_system   212 non-null    object
#  5   symmetry__symbol           212 non-null    object
#  6   symmetry__number           212 non-null    int64
#  7   symmetry__point_group      212 non-null    object
#  8   symmetry__symprec          212 non-null    float64
#  9   symmetry__version          212 non-null    object
#  10  formation_energy_per_atom  212 non-null    float64
#  11  energy_above_hull          212 non-null    float64
#  12  is_stable                  212 non-null    bool
# ...

# %%
df['formula_pretty'].value_counts()
# Out:
# TiO2          23
# Ti17(NO4)6    21
# Ti2N2O        20
# CaCO3         16
# TiO           13
# Ti            10
# Ti3O5          9
# CaO            8
# Ti2O3          7
# Ti2O           7
# Ti3O           6
# TiN            4
# CaO2           4
# Ti3N2O3        4
# Ca(CO2)2       3
# CaC2O5         3
# Ti3O7          3
# Ti3N4          3
# Ti9O10         2
# Ti3O4          2
# Ti2N           2
# Ti4O7          2
# Ti11O14        2
# Ti3N           2
# Ti3N2          2
# Ti6O11         2
# CaO10          2
# Ti6O           2
# Ti7O8          1
# Ti7O13         1
# Ti8O13         1
# Ti19N25        1
# Ti8O15         1
# Ti9O13         1
# Ti9O17         1
# Ti5O9          1
# Ti(NO3)4       1
# Ti9O8          1
# Ti3O2          1
# Ti5O8          1
# Ti10O13        1
# Ti8N5          1
# TiN2           1
# Ca2O3          1
# Ca(CO)4        1
# CaCO4          1
# Ti10O11        1
# Ti11O18        1
# Ti5O7          1
# Ti13O22        1
# Ti19O30        1
# Ti2O7          1
# ...

# %%
df['volume'].value_counts()
# Out:
# 428.698696     2
# 428.097198     2
# 487.283476     1
# 28.344976      1
# 1205.337361    1
#               ..
# 111.979493     1
# 1393.560409    1
# 1373.457681    1
# 1387.410586    1
# 185.907408     1
# Name: volume, Length: 210, dtype: int64

# %%
df['symmetry__crystal_system'].value_counts()
# Out:
# Triclinic       80
# Monoclinic      42
# Orthorhombic    27
# Trigonal        22
# Tetragonal      18
# Cubic           12
# Hexagonal       11
# Name: symmetry__crystal_system, dtype: int64

# %%
df['symmetry__symbol'].value_counts()
# Out:
# P1          54
# P-1         26
# C2/m        14
# P2_1/m       9
# I4/mmm       7
# Pnma         7
# Cmcm         6
# P6_3/mmc     5
# C2/c         5
# Fm-3m        5
# P2_1/c       4
# R-3c         4
# Cm           4
# P-3m1        3
# Pbca         3
# P2/m         3
# Pmmn         3
# I4/m         3
# Pm-3m        3
# P-31c        3
# I4_1/amd     2
# C2           2
# P-62m        2
# P3m1         2
# R-3m         2
# Cmce         2
# P-4m2        2
# P4/mcc       2
# R3m          2
# P321         1
# P-31m        1
# P2/c         1
# Ama2         1
# Pbcn         1
# Pa-3         1
# P4_2/mnm     1
# Imma         1
# P-6m2        1
# P31c         1
# R-3          1
# Cmmm         1
# P312         1
# P6_3/mcm     1
# F-43m        1
# I4/mcm       1
# Im-3m        1
# P6/mmm       1
# P3_1         1
# Fd-3m        1
# P6_522       1
# C222_1       1
# Cmc2_1       1
# Name: symmetry__symbol, dtype: int64

# %%
df['symmetry__point_group'].value_counts()
# Out:
# 1        54
# 2/m      36
# -1       26
# mmm      24
# -3m      13
# 4/mmm    13
# m-3m     10
# 6/mmm     7
# 3m        5
# m         4
# -6m2      3
# 4/m       3
# 2         2
# 32        2
# -42m      2
# mm2       2
# 622       1
# 3         1
# 222       1
# -43m      1
# -3        1
# m-3       1
# Name: symmetry__point_group, dtype: int64

# %%
df['symmetry__version'].value_counts() #drop
# Out:
# 2.0.2    212
# Name: symmetry__version, dtype: int64

# %%
df['ordering'].value_counts()
# Out:
# NM     163
# FM      44
# FiM      3
# AFM      1
# Name: ordering, dtype: int64

# %%
df['ordering'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 207    False
# 208    False
# 209    False
# 210    False
# 211    False
# Name: ordering, Length: 212, dtype: bool

# %%
df['is_stable'].value_counts().to_dict()
# Out:
# {False: 198, True: 14}

# %%
df['is_stable'].replace({False: 0, True: 1},inplace=True)
df['is_metal'].replace({False: 0, True: 1},inplace=True)
df['theoretical'].replace({False: 0, True: 1},inplace=True)
df['is_gap_direct'].replace({False: 0, True: 1},inplace=True)

# %%
df['symmetry__crystal_system']
df['symmetry__symbol']
df['symmetry__point_group']

# %%
df
# Out:
#      nsites formula_pretty      volume   density symmetry__crystal_system  \
# 0        44        Ti19N25  487.283476  4.292537                 Trigonal
# 1         6           Ti2N   75.787718  4.808925               Tetragonal
# 2         6           Ti2N   74.005460  4.924737               Tetragonal
# 3         4           Ti3N   52.721158  4.964112               Tetragonal
# 4         4           Ti3N   50.526036  5.179780                    Cubic
# ..      ...            ...         ...       ...                      ...
# 207      16        Ti3N2O3  183.048704  3.984462               Monoclinic
# 208      16        Ti3N2O3  188.522001  3.868782             Orthorhombic
# 209      16        Ti3N2O3  183.615175  3.972170             Orthorhombic
# 210      16        Ti3N2O3  187.974167  3.880058               Monoclinic
# 211      16         Ti3NO4  185.907408  3.958791             Orthorhombic
#
#     symmetry__symbol  symmetry__number symmetry__point_group  \
# ...

# %%
df=pd.get_dummies(df,columns=['symmetry__crystal_system','symmetry__symbol','symmetry__point_group'])

# %%
df
# Out:
#      nsites formula_pretty      volume   density  symmetry__number  \
# 0        44        Ti19N25  487.283476  4.292537               166
# 1         6           Ti2N   75.787718  4.808925               141
# 2         6           Ti2N   74.005460  4.924737               136
# 3         4           Ti3N   52.721158  4.964112               139
# 4         4           Ti3N   50.526036  5.179780               221
# ..      ...            ...         ...       ...               ...
# 207      16        Ti3N2O3  183.048704  3.984462                 8
# 208      16        Ti3N2O3  188.522001  3.868782                36
# 209      16        Ti3N2O3  183.615175  3.972170                63
# 210      16        Ti3N2O3  187.974167  3.880058                 8
# 211      16         Ti3NO4  185.907408  3.958791                63
#
#      symmetry__symprec symmetry__version  formation_energy_per_atom  \
# 0                  0.1             2.0.2                  -1.309149
# ...

# %%
df=df.drop('symmetry__version',axis=1)

# %%
df
# Out:
#      nsites formula_pretty      volume   density  symmetry__number  \
# 0        44        Ti19N25  487.283476  4.292537               166
# 1         6           Ti2N   75.787718  4.808925               141
# 2         6           Ti2N   74.005460  4.924737               136
# 3         4           Ti3N   52.721158  4.964112               139
# 4         4           Ti3N   50.526036  5.179780               221
# ..      ...            ...         ...       ...               ...
# 207      16        Ti3N2O3  183.048704  3.984462                 8
# 208      16        Ti3N2O3  188.522001  3.868782                36
# 209      16        Ti3N2O3  183.615175  3.972170                63
# 210      16        Ti3N2O3  187.974167  3.880058                 8
# 211      16         Ti3NO4  185.907408  3.958791                63
#
#      symmetry__symprec  formation_energy_per_atom  energy_above_hull  \
# 0                  0.1                  -1.309149           0.368609
# ...

# %%
 16  ordering                   211 non-null    object 
 17  total_magnetization        211 non-null    float64
 18  universal_anisotropy

# %%
df["ordering"].value_counts()
# Out:
# NM     163
# FM      44
# FiM      3
# AFM      1
# Name: ordering, dtype: int64

# %%
df["ordering"].isna().sum()
# Out:
# 1

# %%
df["ordering"].fillna(df["ordering"].mode()[0],inplace=True)

# %%
df["ordering"].isna().sum()
# Out:
# 0

# %%
df["ordering"].value_counts()
# Out:
# NM     164
# FM      44
# FiM      3
# AFM      1
# Name: ordering, dtype: int64

# %%
df=pd.get_dummies(df,columns=["ordering"])

# %%
df
# Out:
#      nsites formula_pretty      volume   density  symmetry__number  \
# 0        44        Ti19N25  487.283476  4.292537               166
# 1         6           Ti2N   75.787718  4.808925               141
# 2         6           Ti2N   74.005460  4.924737               136
# 3         4           Ti3N   52.721158  4.964112               139
# 4         4           Ti3N   50.526036  5.179780               221
# ..      ...            ...         ...       ...               ...
# 207      16        Ti3N2O3  183.048704  3.984462                 8
# 208      16        Ti3N2O3  188.522001  3.868782                36
# 209      16        Ti3N2O3  183.615175  3.972170                63
# 210      16        Ti3N2O3  187.974167  3.880058                 8
# 211      16         Ti3NO4  185.907408  3.958791                63
#
#      symmetry__symprec  formation_energy_per_atom  energy_above_hull  \
# 0                  0.1                  -1.309149           0.368609
# ...

# %%
df["total_magnetization"].fillna(df["total_magnetization"].median(),inplace=True)

# %%
df["universal_anisotropy"].isna().sum()
# Out:
# 176

# %%
df["universal_anisotropy"].value_counts()
# Out:
#  0.311      1
#  0.730      1
#  0.448      1
#  0.474      1
#  0.711      1
#  1.241      1
#  0.565      1
#  1.266      1
#  0.305      1
#  9.598      1
#  0.006      1
#  0.067      1
#  0.043      1
#  7.849      1
#  2.523      1
#  0.371      1
#  0.128      1
# -6.068      1
#  0.220      1
#  1.719      1
#  3.079      1
#  160.923    1
# -4.972      1
#  0.216      1
#  11.616     1
#  0.089      1
#  0.001      1
# -3.398      1
#  0.096      1
#  1.479      1
# -5.992      1
#  1.246      1
#  0.548      1
#  163.460    1
#  1.478      1
#  0.372      1
# Name: universal_anisotropy, dtype: int64

# %%
df=df.drop("universal_anisotropy",axis=1)

# %%
df
# Out:
#      nsites formula_pretty      volume   density  symmetry__number  \
# 0        44        Ti19N25  487.283476  4.292537               166
# 1         6           Ti2N   75.787718  4.808925               141
# 2         6           Ti2N   74.005460  4.924737               136
# 3         4           Ti3N   52.721158  4.964112               139
# 4         4           Ti3N   50.526036  5.179780               221
# ..      ...            ...         ...       ...               ...
# 207      16        Ti3N2O3  183.048704  3.984462                 8
# 208      16        Ti3N2O3  188.522001  3.868782                36
# 209      16        Ti3N2O3  183.615175  3.972170                63
# 210      16        Ti3N2O3  187.974167  3.880058                 8
# 211      16         Ti3NO4  185.907408  3.958791                63
#
#      symmetry__symprec  formation_energy_per_atom  energy_above_hull  \
# 0                  0.1                  -1.309149           0.368609
# ...

# %%
x=df.drop('formula_pretty',axis=1)
x
# Out:
#      nsites      volume   density  symmetry__number  symmetry__symprec  \
# 0        44  487.283476  4.292537               166                0.1
# 1         6   75.787718  4.808925               141                0.1
# 2         6   74.005460  4.924737               136                0.1
# 3         4   52.721158  4.964112               139                0.1
# 4         4   50.526036  5.179780               221                0.1
# ..      ...         ...       ...               ...                ...
# 207      16  183.048704  3.984462                 8                0.1
# 208      16  188.522001  3.868782                36                0.1
# 209      16  183.615175  3.972170                63                0.1
# 210      16  187.974167  3.880058                 8                0.1
# 211      16  185.907408  3.958791                63                0.1
#
#      formation_energy_per_atom  energy_above_hull  is_stable  band_gap  \
# ...

# %%
y=df['formula_pretty']
y
# Out:
# 0      Ti19N25
# 1         Ti2N
# 2         Ti2N
# 3         Ti3N
# 4         Ti3N
#         ...
# 207    Ti3N2O3
# 208    Ti3N2O3
# 209    Ti3N2O3
# 210    Ti3N2O3
# 211     Ti3NO4
# Name: formula_pretty, Length: 212, dtype: object

# %%
df['formula_pretty'].nunique()
# Out:
# 56

# %%
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# %%
KMean_model=KMeans(n_clusters=56)
y_pred=KMean_model.fit_predict(x)

# %%
y_pred
# Out:
# array([ 9, 32, 32, 50, 34, 44, 17, 36, 53, 32, 28,  9, 12, 12, 12, 50, 45,
#        32, 24, 17, 20, 20, 20, 12, 39, 26, 35,  0, 18, 43, 50, 35, 30, 42,
#         2, 33,  4,  7, 15,  4, 46, 13, 51,  6,  8, 44, 23, 15, 23, 55, 16,
#        18, 14, 15, 27,  6,  5,  5,  5,  5,  5, 49, 12, 39, 12, 31,  4, 55,
#        55, 25, 22, 21,  0, 15, 41, 41, 41, 41, 41, 23, 15, 15, 24, 44, 25,
#         6, 19, 10, 10, 10,  6, 17, 26, 44, 32, 38, 18,  1, 29, 29, 52, 29,
#        18, 18, 24, 25, 13, 21, 28, 32, 38,  2, 21, 53, 31, 25,  6,  6, 19,
#        46, 31, 18, 35, 21,  4,  4, 55, 48, 19, 39, 15, 11, 11, 11, 51, 52,
#        12,  2, 47, 49, 49, 34, 12,  8,  9, 39, 28,  8, 17, 23, 37, 51,  3,
#        54, 51, 14, 13,  9,  8, 28, 47,  0,  8, 17, 23,  7,  3, 48,  3,  3,
#         3,  3,  3,  3,  3,  3,  3,  3, 40,  3,  3,  3,  3,  3, 40,  3,  3,
#        31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,  4, 31,
#        31, 31, 31, 18, 24, 24, 18, 24])

# %% [markdown]
# # Single User Input

# %%
x.head(1).T
# Out:
#                                     0
# nsites                      44.000000
# volume                     487.283476
# density                      4.292537
# symmetry__number           166.000000
# symmetry__symprec            0.100000
# ...                               ...
# symmetry__point_group_mmm    0.000000
# ordering_AFM                 0.000000
# ordering_FM                  0.000000
# ordering_FiM                 0.000000
# ordering_NM                  1.000000
#
# [98 rows x 1 columns]

# %%
nsites=44.000000                                   
volume=487.283476                                 
density=4.292537                                
symmetry__number=0.100000                         
symmetry__symprec=0.1                    
formation_energy_per_atom=-1.43             
energy_above_hull=0.02086                      
is_stable=0                              
band_gap=0.0000                              
is_gap_direct=1                           
is_metal=0                                 
total_magnetization=1.1227                    
theoretical=1.12231                             
symmetry__crystal_system='Hexagonal'      
symmetry__symbol='C2/c'                    
symmetry__point_group='2/m'            
ordering='AFM'                           

symmetry__crystal_system="symmetry__crystal_system_"+symmetry__crystal_system
symmetry__symbol='symmetry__symbol_'+symmetry__symbol
symmetry__point_group='symmetry__point_group_'+symmetry__point_group
ordering='ordering_'+ordering

# %%
column_names = x.columns
column_names
# Out:
# Index(['nsites', 'volume', 'density', 'symmetry__number', 'symmetry__symprec',
#        'formation_energy_per_atom', 'energy_above_hull', 'is_stable',
#        'band_gap', 'is_gap_direct', 'is_metal', 'total_magnetization',
#        'theoretical', 'symmetry__crystal_system_Cubic',
#        'symmetry__crystal_system_Hexagonal',
#        'symmetry__crystal_system_Monoclinic',
#        'symmetry__crystal_system_Orthorhombic',
#        'symmetry__crystal_system_Tetragonal',
#        'symmetry__crystal_system_Triclinic',
#        'symmetry__crystal_system_Trigonal', 'symmetry__symbol_Ama2',
#        'symmetry__symbol_C2', 'symmetry__symbol_C2/c', 'symmetry__symbol_C2/m',
#        'symmetry__symbol_C222_1', 'symmetry__symbol_Cm',
#        'symmetry__symbol_Cmc2_1', 'symmetry__symbol_Cmce',
#        'symmetry__symbol_Cmcm', 'symmetry__symbol_Cmmm',
#        'symmetry__symbol_F-43m', 'symmetry__symbol_Fd-3m',
#        'symmetry__symbol_Fm-3m', 'symmetry__symbol_I4/m',
# ...

# %% [markdown]
# ## create pickle file

# %%
import pickle

with open("anurag.pkl", "wb") as f:
    pickle.dump(KMean_model, f)

# %% [markdown]
# ## create json file

# %%
json_data = {"columns" : list(column_names)}

json_data
# Out:
# {'columns': ['nsites',
#   'volume',
#   'density',
#   'symmetry__number',
#   'symmetry__symprec',
#   'formation_energy_per_atom',
#   'energy_above_hull',
#   'is_stable',
#   'band_gap',
#   'is_gap_direct',
#   'is_metal',
#   'total_magnetization',
#   'theoretical',
#   'symmetry__crystal_system_Cubic',
#   'symmetry__crystal_system_Hexagonal',
#   'symmetry__crystal_system_Monoclinic',
#   'symmetry__crystal_system_Orthorhombic',
#   'symmetry__crystal_system_Tetragonal',
#   'symmetry__crystal_system_Triclinic',
#   'symmetry__crystal_system_Trigonal',
#   'symmetry__symbol_Ama2',
#   'symmetry__symbol_C2',
#   'symmetry__symbol_C2/c',
#   'symmetry__symbol_C2/m',
#   'symmetry__symbol_C222_1',
#   'symmetry__symbol_Cm',
#   'symmetry__symbol_Cmc2_1',
#   'symmetry__symbol_Cmce',
#   'symmetry__symbol_Cmcm',
#   'symmetry__symbol_Cmmm',
#   'symmetry__symbol_F-43m',
#   'symmetry__symbol_Fd-3m',
#   'symmetry__symbol_Fm-3m',
#   'symmetry__symbol_I4/m',
# ...

# %%
import json

with open("anurag.json", "w") as f:
    json.dump(json_data, f)

# %%
test_array = np.zeros(len(x.columns))
test_array[0] = nsites                                   
test_array[1] = volume                                 
test_array[2] = density                                
test_array[3] = symmetry__number                         
test_array[4] = symmetry__symprec                      
test_array[5] = formation_energy_per_atom              
test_array[6] = energy_above_hull                      
test_array[7]= energy_above_hull                      
test_array[8]=is_stable                               
test_array[9]=band_gap                               
test_array[10]=is_gap_direct                            
test_array[11]=is_metal                                 
test_array[12]=total_magnetization                    
test_array[13]=theoretical                              
test_array[14]=symmetry__crystal_system_Cubic          
test_array[15]=symmetry__crystal_system_Hexagonal       
test_array[16]=symmetry__crystal_system_Monoclinic      
test_array[17]=symmetry__crystal_system_Orthorhombic    
test_array[18]=symmetry__crystal_system_Tetragonal      
test_array[19]=symmetry__crystal_system_Triclinic       
test_array[20]=symmetry__crystal_system_Trigonal       
test_array[21]=symmetry__symbol_Ama2                    
test_array[22]=symmetry__symbol_C2                      
test_array[23]=symmetry__symbol_C2/c                    
test_array[24]=symmetry__symbol_C2/m                   
test_array[25]=symmetry__symbol_C222_1                 
test_array[]=symmetry__symbol_Cm                      
symmetry__symbol_Cmc2_1                  
symmetry__symbol_Cmce                   
symmetry__symbol_Cmcm                    
symmetry__symbol_Cmmm                   
symmetry__symbol_F-43m                 
symmetry__symbol_Fd-3m                   
symmetry__symbol_Fm-3m                  
symmetry__symbol_I4/m                    
symmetry__symbol_I4/mcm                 
symmetry__symbol_I4/mmm                 
symmetry__symbol_I4_1/amd                
symmetry__symbol_Im-3m                  
symmetry__symbol_Imma                   
symmetry__symbol_P-1                     
symmetry__symbol_P-31c                  
symmetry__symbol_P-31m                  
symmetry__symbol_P-3m1                  
symmetry__symbol_P-4m2                  
symmetry__symbol_P-62m                  
symmetry__symbol_P-6m2                 
symmetry__symbol_P1                     
symmetry__symbol_P2/c                    
symmetry__symbol_P2/m                    
symmetry__symbol_P2_1/c                  
symmetry__symbol_P2_1/m                 
symmetry__symbol_P312                    
symmetry__symbol_P31c                   
symmetry__symbol_P321                   
symmetry__symbol_P3_1                    
symmetry__symbol_P3m1                    
symmetry__symbol_P4/mcc                  
symmetry__symbol_P4_2/mnm                
symmetry__symbol_P6/mmm                  
symmetry__symbol_P6_3/mcm                
symmetry__symbol_P6_3/mmc                
symmetry__symbol_P6_522                  
symmetry__symbol_Pa-3                   
symmetry__symbol_Pbca                    
symmetry__symbol_Pbcn                   
symmetry__symbol_Pm-3m                  
symmetry__symbol_Pmmn                    
symmetry__symbol_Pnma                    
symmetry__symbol_R-3                     
symmetry__symbol_R-3c                   
symmetry__symbol_R-3m                    
symmetry__symbol_R3m                     
symmetry__point_group_-1                
symmetry__point_group_-3                
symmetry__point_group_-3m                
symmetry__point_group_-42m               
symmetry__point_group_-43m               
symmetry__point_group_-6m2               
symmetry__point_group_1                 
symmetry__point_group_2                  
symmetry__point_group_2/m                
symmetry__point_group_222               
symmetry__point_group_3                
symmetry__point_group_32                
symmetry__point_group_3m                 
symmetry__point_group_4/m               
symmetry__point_group_4/mmm              
symmetry__point_group_6/mmm             
symmetry__point_group_622                
symmetry__point_group_m                  
symmetry__point_group_m-3                
symmetry__point_group_m-3m              
symmetry__point_group_mm2              
symmetry__point_group_mmm               
ordering_AFM                            
ordering_FM                             
ordering_FiM                          
ordering_NM
